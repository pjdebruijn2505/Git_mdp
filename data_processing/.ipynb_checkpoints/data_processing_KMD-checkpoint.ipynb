# %% [markdown]
# # Data processing KMD data
# Due to the fact that only part of the KMD weather data was provided and only near the end of the project, currently no KMD data is being used for the model. However, if more data was provided this notebook would be able to visualize it so if the dataset is complete in the end in can be combined with the CHIRPS remote sensing dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import glob
import platform
import pathlib  
import os.path
import netCDF4 as nc
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from shapely.geometry import Point

# %%
# For data safety reasons a local path is used to save the data. Both paths noted here are paths of the 
# programmers who worked on the Hydrological models. Please replace with your own path.


cwd = pathlib.Path().resolve()
src = cwd.parent
data = src.parent.parent.parent
OS_type = platform.system()

if OS_type == 'Darwin':
    username = 'Mats '
    data_path = os.path.join(data, 'data_tana', 'TAHMO', 'location_tahmo')
    shape_path = gpd.read_file(os.path.join(data_path, 'total_tana_catchement_area_clip_projected.gpkg'))
else:
    username = 'Mootje'
    data_path = os.path.join(data, 'OneDrive - Delft University of Technology', 'TU Delft', 'Master ENVM', 'MDP', 'Model', 'Data', 'KMD')
    shape_path = os.path.join(data, 'OneDrive - Delft University of Technology', 'TU Delft', 'Master ENVM', 'MDP', 'Model', 'Data', 'Shapefiles')

print(f"Welcome {username}, have a wondeful day on your {OS_type} machine. Your data should be located in {data_path}")
# Out:
# Welcome Mootje, have a wondeful day on your Windows machine. Your data should be located in C:\Users\Moniek van Zon\OneDrive - Delft University of Technology\TU Delft\Master ENVM\MDP\Model\Data\KMD

# %%
#Load in the dataset contained in the .NetCDF file(s)
data_files = glob.glob(os.path.join(data_path, 'rr_mrg_20180101_CLM.nc'))
datasets = {}

# Loop through the Netcdf file and assign the correct coordinates to be able to plot the dataset as Geopandas \
# dataframe. Prints the xarray file in the end for manual inspection of the file structure.

for file_path in data_files:
    
    # Extract the file identifier from the file name to be added as the time coordinate (the file name)
    # originally contained the date only as part of the file name. 
    file_name = os.path.basename(file_path)  
    file_identifier = file_name.split('_')[0] 
    dataset = xr.open_dataset(file_path)
    dataset = dataset.assign_coords(file_identifier=file_identifier)
    
    # Add the dataset to the dictionary with the file identifier as the key
    datasets[file_identifier] = dataset

# Print xarray data structure for manual inspection if desired.    
datasets['rr']
# Out:
# <xarray.Dataset> Size: 10kB
# Dimensions:          (Lon: 64, Lat: 35)
# Coordinates:
#   * Lon              (Lon) float64 512B 36.58 36.62 36.68 ... 39.62 39.68 39.73
#   * Lat              (Lat) float64 280B -1.225 -1.175 -1.125 ... 0.425 0.475
#     file_identifier  <U2 8B 'rr'
# Data variables:
#     precip           (Lat, Lon) float32 9kB ...

# %%
# plot the catchment area

shape_file = os.path.join(shape_path, '*.gpkg')
shape_files = glob.glob(shape_file)
gdfs = []

for file in shape_files:
    gdf = gpd.read_file(file)
    gdfs.append(gdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # plot the catchment area
# ----> 2 shape_path = os.path.join(data, 'OneDrive - Delft University of Technology', 'TU Delft', 'Master ENVM', 'MDP', 'Model', 'Data', 'Shapefiles')
#       3 shape_file = os.path.join(shape_path, '*.gpkg')
#       4 shape_files = glob.glob(shape_file)
#
# NameError: name 'os' is not defined

# %%
fig, ax = plt.subplots(figsize=(10, 8)) 
merged_gdfs.plot(ax=ax, color = 'bisque', edgecolor = 'black')
datasets['rr']['precip'].plot(x = 'Lon', y = 'Lat', cmap = 'viridis', alpha = 0.8)
ax.set_xlim(36.5, 42)
ax.set_ylim(-3.5, 1)
plt.title('Rainfall in mm for the Tana Basin based on KMD data')
plt.show()
